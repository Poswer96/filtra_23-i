# %% [markdown]
# # Concepto de filtros pasa baja con aproximación Chebyshev

# %%
#NOTE importar bibliotecas
import sympy as sym

import numpy             as np
import matplotlib.pyplot as plt

from scipy import signal
from sympy import Poly   as poly

# %%
def cheby_poly(n,N,Tn,Tnp,X):
    Tnx = 0
    if n < N-1:
        Tnx = 2*w*Tn - Tnp
        cheby_poly(n+1,N,Tnx,Tn,X)
        X.append(Tnx)

# %%
def freqs_bode(sy):
    w, mag, phase = signal.bode(sy)
    
    plt.figure(figsize=(15,5))
    plt.semilogx(w, mag,linewidth=3)
    plt.grid(True)
    
    plt.figure(figsize=(15,5))
    plt.semilogx(w, phase, linewidth=3, color='orange')
    plt.grid(True)
    plt.show()

# Definicion de funcion para graficar respuesta en frecuencia del filtro
def freqz_plot(b,a,sr):
    w, h = signal.freqz(b,a)
    h[h==0] = 1E-5
    
    H    = 20*np.log10( np.abs(h) )
    W    = np.angle  (h)
    W    = np.unwrap (W)
    W    = np.degrees(W)
    w    = np.linspace(0,sr/2,H.shape[0] )
    
    return w, W, H

# %%
R_db = 1.
wp   = 50.
ws   = 90.
A    = 10.

# %%
eps    = np.sqrt( np.power( 10,1/R_db ) - 1 )
n_tmp  = ( np.cosh(  np.sqrt(  (A**2 - 1)/eps**2  )  )/
               np.cosh(  ws/wp ) )
n      = np.ceil(n_tmp)

print('eps: {:4.4f}, n: {:4.4f}, n: {:d}'.format( eps,n_tmp,int(n) )  )
# Out:
# eps: 3.0000, n: 4.4415, n: 5

# %%
k   = np.arange(1,n+1)

G = (  1 + np.sqrt( 1 + eps**2 )/eps  )
G = G**(1./n)

r0 = ( G**2 + 1 )/(2*G)
r1 = ( G**2 - 1 )/(2*G)

print ('r0={:6.4f}, r1={:6.4f}'.format(r0,r1))

p  = np.pi*(2*k + n - 1 )/(2*n)

plt.figure(figsize=(6,6))
plt.plot(  r1*np.cos(p),r0*np.sin(p),'ro',markersize=15 )
plt.axes().set_aspect('equal', 'datalim')
plt.grid(True)
plt.show()
# Out:
# r0=1.0104, r1=0.1445

# %%
for i,j in zip( r1*np.cos(p),r0*np.sin(p) ):
    print( '{:7.4f} + {:7.4f}j'.format(i,j) )
# Out:
# -0.0446 +  0.9609j
# -0.1169 +  0.5939j
# -0.1445 +  0.0000j
# -0.1169 + -0.5939j
# -0.0446 + -0.9609j

# %%
s, z = sym.symbols('s z')
sh   = int( p.shape[0]/2 )

spkr, spki = r1*np.cos(p[:sh]), 1j*r0*np.sin(p[:sh])

P = []
for pkr, pki in zip(spkr,spki):
    pk = ( s-( pkr + pki ) )*( s-( pkr - pki ) )
    P  .append(pk.expand() )
    print(     pk.expand() )

if p.shape[0]%2 != 0:
    P.append( s-r1*np.cos( p[p.shape[0]%2 + 1] ) )
    print( P[-1] )
# Out:
# s**2 + 0.089284076212886*s + 0.925378538056029
# s**2 + 0.233748746179472*s + 0.366361543681081
# s + 0.144464669966586

# %%
den = 1.
for p in P:
    den *= p

print( den.expand() )
coef = poly( den.expand() ).all_coeffs()
coef = np.array(coef).astype('float')
# Out:
# 1.0*s**5 + 0.467497492358943*s**4 + 1.35927695268095*s**3 + 0.438642113156508*s**2 + 0.374997170898891*s + 0.0489768616526351

# %%
sy = signal.lti( [1],coef )

freqs_bode(sy)

# %%
den = 1.
for p in P:
    den *= p

coef = poly(  ( den ).subs( {s:s/wp} )  ).all_coeffs()
coef = np.array(coef).astype('float')
coef
# Out:
# array([3.20000000e-09, 7.47995988e-08, 1.08742156e-05, 1.75456845e-04,
#        7.49994342e-03, 4.89768617e-02])

# %%
sy = signal.lti( [1],coef )
freqs_bode(sy)

# %%
den = 1.
for p in P:
    den *= p

#coef = poly(  ( 1/den ).subs( {s:wp/s} )  )
coef = (  den.subs( {s:wp/s} )  ).expand()
print( '{},\n'.format(coef) )
# Out:
# 0.0489768616526351 + 18.7498585449445/s + 1096.60528289127/s**2 + 169909.619085119/s**3 + 2921859.3272434/s**4 + 312500000.0/s**5,

# %%
coef = poly(  coef*(s**5)  ).all_coeffs()
coef = np.array(coef).astype('float')
print(coef)
# Out:
# [4.89768617e-02 1.87498585e+01 1.09660528e+03 1.69909619e+05
#  2.92185933e+06 3.12500000e+08]

# %%
sy = signal.lti( [1, 0, 0, 0, 0],coef )
freqs_bode(sy)

# %%
n    = 2.
eps  = .3

k    = np.arange(1,n+1)
p    = np.pi*(2*k + n - 1 )/(2*n)
s, z = sym.symbols('s z')
sh   = int( p.shape[0]/2 )

print p.shape
spkr, spki = r1*np.cos(p[:sh]), 1j*r0*np.sin(p[:sh])

P = []
for pkr, pki in zip(spkr,spki):
    pk = ( s-( pkr + pki ) )*( s-( pkr - pki ) )
    P  .append(pk.expand() )
    print(     pk.expand() )

if p.shape[0]%2 != 0:
    P.append( s-r1*np.cos( p[p.shape[0]%2 + 1] ) )
    print( P[-1] )

den = 1.
for p in P:
    den *= p

print( den.expand() )
coef = poly( den.expand() ).all_coeffs()
coef = np.array(coef).astype('float')

sy = signal.lti( [1],coef )

freqs_bode(sy)
# Out:
# (2,)
# s**2 + 0.204303895550499*s + 0.520870040868555
# 1.0*s**2 + 0.204303895550499*s + 0.520870040868555

# %%
sr = 50.
H  = sym.cancel( den.subs({ s:(2*sr*(1-z**-1)/(1+z**-1)) })  )
b, a =sym.fraction(H)
print( '{} // {}'.format(b,a) )
# Out:
# 10020.9512595959*z**2 - 19998.9582599183*z + 9980.09048048582 // 1.0*z**2 + 2.0*z + 1.0

# %%
b = np.array(  poly( b ).all_coeffs()  ).astype('float')
a = np.array(  poly( a ).all_coeffs()  ).astype('float')

print( '{} // {}'.format(b,a) )
# Out:
# [ 10020.9512596  -19998.95825992   9980.09048049] // [1. 2. 1.]

# %%
w, W, H, = freqz_plot(a,b,sr)

plt.figure(u'Respuesta en frecuencia dB',figsize=(12,5))
plt.plot(w,H,'b',linewidth=3)
plt.grid(True)
plt.figure(u'Respuesta en frecuencia Hz',figsize=(12,5))
plt.plot(w,W,'g',linewidth=3)
plt.grid(True)
plt.show()

# %%
wt  = np.linspace(0.001,1.1,200)
tn = np.array(  [ X[0].subs({'w':i}) for i in wt ]   )

plt.figure(figsize=(12,5))
plt.plot(wt,tn,color='green',linewidth=3)
plt.grid(True)

# %%
eps = 0.1

H = 1/(1 + (eps*tn)**2 )

plt.figure(figsize=(12,5))
plt.plot(wt,H,color='green',linewidth=3)
plt.grid(True)

# %%
N   = 5
eps = .1

k = np.arange(1,N+1)

sg_k = -np.sin( (2*k-1.)*np.pi/(2*N) )*np.sinh( 1./N*np.arcsinh(1./eps) )
w_k  =  np.cos( (2*k-1.)*np.pi/(2*N) )*np.cosh( 1./N*np.arcsinh(1./eps) )

# %%
plt.figure(figsize=(5,5))
plt.plot(sg_k,w_k,'o',markersize=10)
plt.grid(True)
plt.axes().set_aspect('equal', 'datalim')

# %%
l = int(sg_k.shape[0]/2)
B = -2*sg_k
W = sg_k**2 + w_k**2

for i,j in zip(B,W):
    print ('S**2 +{:5.4f} S + {:5.4f}'.format(i,j))
# Out:
# S**2 +0.3932 S + 1.3093
# S**2 +1.0294 S + 0.7503
# S**2 +1.2725 S + 0.4048
# S**2 +1.0294 S + 0.7503
# S**2 +0.3932 S + 1.3093

# %%
n   = 6
k   = np.arange(1,2*n+1)
eps = .1

G = (  1 + np.sqrt( 1 + eps**2 )/eps  )
G = G**(1./n)

r0 = ( G**2 + 1 )/(2*G)
r1 = ( G**2 - 1 )/(2*G)

print ('r0={:6.4f}, r1={:6.4f}'.format(r0,r1))

p  = np.pi*(2*k + n - 1 )/(2*n)

plt.figure(figsize=(6,6))
plt.plot(  r1*np.cos(p),r0*np.sin(p),'ro',markersize=15 )
#plt.plot( -r1*np.sin(p),r0*np.cos(p),'ko',markersize=9 )
plt.plot(  r0*np.cos(p),r0*np.sin(p),'go',markersize=10 )
plt.plot(  r1*np.cos(p),r1*np.sin(p),'bo',markersize=10 )
plt.axes().set_aspect('equal', 'datalim')
plt.grid(True)
plt.show()
# Out:
# r0=1.0812, r1=0.4112

# %%
n   = 8
k   = np.arange(1,n+1)
eps = .01

G = (  1 + np.sqrt( 1 + eps**2 )/eps  )
G = G**(1./n)

r0 = ( G**2 + 1 )/(2*G)
r1 = ( G**2 - 1 )/(2*G)

p  = np.pi*(2*k + n - 1 )/(2*n)

S = sym.symbols('S')

A, B = r1*np.cos(p),r0*np.sin(p)
Pk   = []
l    = int( n/2 )
for i,j in zip( A[:l],B[:l] ):
    pk = (S -i-1j*j)*(S -i+1j*j)
    Pk.append(pk)
    print ( pk ).expand()

if n%2!=0:
    print ('polo real: {:6.4f}'.format( -A[l]) )
    Pk.append(S-A[l])
# Out:
# S**2 + 0.237788719047078*S + 1.33334759368678
# S**2 + 0.677164980226423*S + 1.06274954361368
# S**2 + 1.01344901168213*S + 0.680066111248588
# S**2 + 1.1954446180474*S + 0.40946806117549

# %%
w  = np.linspace( 0,4,1000 )
p2 = 2*w**2 - 1
p4 = 8*w**4 - 8*w**2 + 1
e = .5

H2 = 1/( 1+e**2*p2**2 )
H4 = 1/( 1+e**2*p4**2 )

plt.figure(figsize=(12,6))
plt.plot( w,H2, 'r', linewidth=3 )
plt.plot( w,H4, 'b', linewidth=3 )
plt.grid(True)
plt.show()

# %%
w  = np.linspace( 0,4,1000 )
p3 = 4*w**3  - 3*w
p5 = 16*w**5 - 20*w**3 + 5*w
e = .3

H3 = 1/( 1+e**2*p3**2 )
H5 = 1/( 1+e**2*p5**2 )

plt.figure(figsize=(12,6))
plt.plot( w,H3, 'r', linewidth=3 )
plt.plot( w,H5, 'b', linewidth=3 )
plt.grid(True)
plt.show()

# %%
w  = np.linspace( 0.0001,5,1000 )
wt = w
p5 = 16*wt**5 - 20*wt**3 + 5*wt
e1 = .1
e2 = .3

H5_1 = 1/( 1+e1**2*p5**2 )
H5_2 = 1/( 1+e2**2*p5**2 )

plt.figure(figsize=(12,6))
plt.plot( w,H5_1, 'r', linewidth=3 )
plt.plot( w,H5_2, 'b', linewidth=3 )
plt.grid(True)
plt.show()
